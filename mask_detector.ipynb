# %%
# %load_ext autoreload
# %autoreload 2

# %%
from mask_detector import MaskDetector
import PIL.Image as Image

# %% [markdown]
# ## Mask detection

# %% [markdown]
# First we will open an image

# %%
frame = Image.open('images/mask-no-mask.jpg')

# %% [markdown]
# Next we need to intiallize our detector

# %%
mask_detector = MaskDetector('models/mask-classifier.pkl', image_sz=128)
# Out:
# Running on device: cpu

# %% [markdown]
# Finally we can detect on the image

# %%
mask_detector.detect(frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x800 at 0x1A35977940>
